# %%
# Run this app with `python app.py` and
# visit http://127.0.0.1:8050/ in your web browser.


from dash import Dash, html, dcc
import plotly.express as px
import pandas as pd

app = Dash()

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas"],
    "Amount": [11, 6, 2, 2, 4, 5],
    "City": ["SF", "SF", "SF", "Montreal", "Montreal", "Montreal"]
})

fig = px.bar(df, x="Fruit", y="Amount", color="City", barmode="group")

app.layout = html.Div(children=[
    html.H1(children='Fortnite Battle Pass'),

    html.Div(children='''
        Dash: A web application framework for your data.
    '''),

    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Run this app with `python app.py` and
# visit http://127.0.0.1:8050/ in your web browser.


from dash import Dash, dcc, html
import plotly.express as px
import pandas as pd

app = Dash()

colors = {
    'background': "#000000",
    'text': "#A11CAD"
}

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas", "Kiwis", "Kiwis"],
    "Amount": [4, 1, 2, 2, 4, 5, 4, 2],
    "City": ["SF", "SF", "SF", "Montreal", "Montreal", "Montreal", "Andre's Room", "Willy's Room"]
})

fig = px.bar(df, x="Fruit", y="Amount", color="City", barmode="group")

fig.update_layout(
    plot_bgcolor=colors['background'],
    paper_bgcolor=colors['background'],
    font_color=colors['text']
)

app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Hello Dash',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),

    html.Div(children='Dash: A web application framework for your data.', style={
        'textAlign': 'center',
        'color': colors['text']
    }),

    dcc.Graph(
        id='example-graph-2',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# [2026-04-19 00:39:40,702] ERROR in app: Exception on /_alive_a097907c-fdeb-4af3-b1d3-919ac26eba56 [GET]
# Traceback (most recent call last):
#   File "c:\Users\xmxze\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 915, in full_dispatch_request
#     rv = self.preprocess_request()
#   File "c:\Users\xmxze\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1291, in preprocess_request
#     rv = self.ensure_sync(before_func)()
#   File "c:\Users\xmxze\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\dash.py", line 1635, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\xmxze\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_validate.py", line 456, in validate_layout
#     _validate(layout_value)
#     ~~~~~~~~~^^^^^^^^^^^^^^
# ...

# %%
# Dash + plotly test one

from dash import Dash, dcc, html
import plotly.express as px
import pandas as pd

app = Dash

colors = {
    'background': '#111111',
    'text': '#111111'

}

df = pd.DataFrame({
    "Cars": [4,8,13,2],
    "Manufacturer": ["Ford", "Ferrari", "Toyota", "Fiat"],
})

fig = px.bar(df, x="Manufacturer", y="Cars")

fig.update_layout(
    plot_bgcolor=colors['background'],
    paper_bgcolor=colors['background'],
    font_color=colors['text']
)

app.layout = html.Div(style={'backgroundColor': colors['background']})

# %% [markdown]
# End of testing, above from documentation on their website.
#
# Plan:
#     -> Setup imports and app running (basics)
#     -> Get CSV dataset read (start locally, then implement the GitHub).
#     -> Choose graphs useful for each output (lines, dials, guages, catagoric handling?)
#     -> Build buttons for users to interact with and change metrics
#     -> Setup layout so all metrics clearly visable and intuitive.
#     -> Think about dynamic visuals (important but to implement later on)
#     -> Make pretty!

# %%
# Import packages
from dash import Dash, html
import dash_ag_grid as dag
import pandas as pd

# Incorporate data
df = pd.read_csv('https://raw.githubusercontent.com/HarryHuckstep/DriveSim-AI-Lboro-Group/refs/heads/main/data/KIT/2017-07-05_Seat_Leon_RT_S_Stau.csv?token=GHSAT0AAAAAAD2RZZ23755UYDVZFSPYKBDW2PEDHAQ')

# Initialize the app
app = Dash()

# App layout
app.layout = [
    html.Div(children='Drive Sim AI'),
    dag.AgGrid(
        rowData=df.to_dict('records'),
        columnDefs=[{"field": i} for i in df.columns]
    )
]

# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
